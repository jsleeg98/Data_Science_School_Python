# %%
import matplotlib as mpl
import matplotlib.pyplot as plt



plt.title('Plot')
plt.plot([1, 4, 8, 16])
plt.show()

# %%
import matplotlib.font_manager

matplotlib.font_manager._rebuild()
sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist if f.name.startswith("Nanum")])
# Out:
# ['NanumGothic', 'NanumGothic', 'NanumGothic', 'NanumGothic']

# %%
mpl.rc('font', family = 'NanumGothic')
mpl.rc('axes', unicode_minus = False)

# %%
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel('엑스축 라벨')
plt.ylabel('와이축 라벨')
plt.show()

# %%
plt.title("rs-- 스타일의 plot")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--', c = 'b', lw = 5, ls = '-.', marker = 'o', ms = 15, mec = 'g', mew = 5, mfc = 'r')
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.grid(True)
plt.show()

# %%
import numpy as np

t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--')
plt.plot(t, t**2, 'bs:')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dfcd0558fd73> in <module>
#       2
#       3 t = np.arange(0., 5., 0.2)
# ----> 4 plt.title("라인 플롯에서 여러개의 선 그리기")
#       5 plt.plot(t, t, 'r--')
#       6 plt.plot(t, t**2, 'bs:')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 데이터 시각화
# # 5.1 시각화 패키지 맷플롯리브 소개
# ## 연습문제 5.1.1
#
# 여러가지 함수를 사용하여 아래 조건에 맞는 그래프를 그린다.
#
# xlabel, ylabel, title을 모두 갖추고 있어야 한다.
#
# 하나의 Figure(일단, 그림이라고 이해한다. 아래에 자세한 설명이 있다.)에 3개 이상의 Plot을 그린다.
#
# 각 Plot은 다른 선, 마크, 색 스타일을 가진다.
#
# legend는 그래프와 겹치지 않는 곳에 위치 시키도록 한다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import FinanceDataReader as fdr 

mpl.rc('font', family= 'NanumGothic')
mpl.rc('axes', unicode_minus = False)


date = pd.date_range('2021-1-11', '2021-1-15')
df_005380 = fdr.DataReader('005380','2021-1-11', '2021-1-15')['Close']
df_005385 = fdr.DataReader('005385','2021-1-11', '2021-1-15')['Close']
df_005930 = fdr.DataReader('005930','2021-1-11', '2021-1-15')['Close']
df_005935 = fdr.DataReader('005935','2021-1-11', '2021-1-15')['Close']

plt.title('현대차 주식 종가 그래프')
plt.xlabel('일자')
plt.ylabel('종가')
plt.plot(date, df_005380, ls = '-', c = 'r', marker = 'o', label = '현대차')
plt.plot(date, df_005385, ls = '-.', c = 'b', marker = 'v', label = '현대차우')
plt.plot(date, df_005930, ls = '--', c = 'g', marker = '^', label = '삼성전자')
plt.plot(date, df_005935, ls = ':', c = 'y', marker = '>', label = '삼성전자우')
plt.legend(loc = 0)
plt.grid(True)
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)
f1 = plt.figure(figsize = (10, 2))
plt.title('figuer size : (10, 2)')
plt.plot(np.random.randn(100))
plt.grid(True)
plt.show()

f1 = plt.figure(1)
plt.title('현재의 figure 객체')
plt.plot([1,2,3,4], 'ro:')

f2 = plt.gcf()
#print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(432x288) 286397552
